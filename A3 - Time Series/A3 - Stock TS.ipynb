# %% [markdown]
# # Assignment 3 - Stock Time Series
# #### 1) In a command window: conda install pandas-datareader

# %%
import numpy as np
import pandas as pd
pd.options.display.max_rows = 6

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### 2) Download the adjusted close price for AAPL, MSFT, IBM, AMZN and EBAY using the following code:

# %%
import pandas_datareader.data as web
import datetime

start = datetime.datetime(2012, 7, 31)
end = datetime.datetime(2017, 6, 30)

# %%
aapl = web.DataReader('WIKI/AAPL', 'quandl', start, end)
msft = web.DataReader('WIKI/MSFT', 'quandl', start, end)
ibm = web.DataReader('WIKI/IBM', 'quandl', start, end)
amzn = web.DataReader('WIKI/AMZN', 'quandl', start, end)
ebay = web.DataReader('WIKI/EBAY', 'quandl', start, end)

# %% [markdown]
# #### 3) Get the data for the last 60 months, select the adjusted monthend close for each.

# %%
aapl
# Out:
#                Open    High       Low   Close      Volume  ExDividend  \
# Date
# 2017-06-30  144.450  144.96  143.7800  144.02  22328979.0         0.0
# 2017-06-29  144.710  145.13  142.2800  143.68  31116980.0         0.0
# 2017-06-28  144.490  146.11  143.1601  145.83  21915939.0         0.0
# ...             ...     ...       ...     ...         ...         ...
# 2012-08-02  602.840  610.69  600.2500  607.79  11862800.0         0.0
# 2012-08-01  615.905  616.40  603.0000  606.81  13732200.0         0.0
# 2012-07-31  603.230  611.70  602.7200  610.76  16511700.0         0.0
#
#             SplitRatio     AdjOpen     AdjHigh      AdjLow    AdjClose  \
# Date
# 2017-06-30         1.0  143.866270  144.374209  143.198978  143.438008
# 2017-06-29         1.0  144.125219  144.543522  141.705039  143.099382
# 2017-06-28         1.0  143.906108  145.519562  142.581583  145.240693
# ...                ...         ...         ...         ...         ...
# 2012-08-02         1.0   77.473342   78.482177   77.140491   78.109486
# 2012-08-01         1.0   79.152377   79.215991   77.493904   77.983543
# 2012-07-31         1.0   77.523463   78.611976   77.457921   78.491173
#
#               AdjVolume
# Date
# 2017-06-30   22328979.0
# 2017-06-29   31116980.0
# 2017-06-28   21915939.0
# ...                 ...
# 2012-08-02   83039600.0
# 2012-08-01   96125400.0
# 2012-07-31  115581900.0
#
# [1238 rows x 12 columns]

# %%
# collect all daily Adjusted Close into one dataframe - df

slist = []

securities = [aapl, msft, ibm, amzn, ebay]
secnames = ['aapl', 'msft', 'ibm', 'amzn', 'ebay']

for s in range(5):
    ser = securities[s].AdjClose
    ser.name = secnames[s]
    slist.append(ser)
            
df = pd.concat(slist, axis=1)
df
# Out:
#                   aapl       msft         ibm    amzn       ebay
# Date
# 2017-06-30  143.438008  68.219505  150.719070  968.00  34.920000
# 2017-06-29  143.099382  67.784040  151.013003  975.93  34.510000
# 2017-06-28  145.240693  69.080538  152.178938  990.33  35.310000
# ...                ...        ...         ...     ...        ...
# 2012-08-02   78.109486  25.187301  165.807770  230.81  17.219829
# 2012-08-01   77.983543  25.377134  166.430242  232.09  17.267039
# 2012-07-31   78.491173  25.428906  167.112403  233.30  17.428339
#
# [1238 rows x 5 columns]

# %%
#preview the daily chart
df.plot(figsize=(8,5));

# %%
#downsample to month end.
df = df.resample('M',convention='end').mean()
df
# Out:
#                   aapl       msft         ibm        amzn       ebay
# Date
# 2012-07-31   78.491173  25.428906  167.112403  233.300000  17.428339
# 2012-08-31   82.859921  26.301014  169.067171  238.993826  18.005549
# 2012-09-30   87.965057  26.736347  174.413623  255.740789  19.238365
# ...                ...        ...         ...         ...        ...
# 2017-04-30  141.728436  65.123601  162.176945  903.405789  33.567632
# 2017-05-31  151.386305  68.016792  149.928795  961.707273  34.025909
# 2017-06-30  147.233064  69.791092  150.746237  990.424091  34.971818
#
# [60 rows x 5 columns]

# %%
#check the monthly chart, which should be similar to the daily chart above
df.plot(figsize=(8,5));

# %% [markdown]
# #### 4) Use pandas autocorrelation_plot to plot the autocorrelation of the adjusted monthend

# %%
plt.figure(figsize=(8,5))
for s in df.columns:
    pd.plotting.autocorrelation_plot(df[s],label=s)

# %% [markdown]
# #### 5) Calculate the monthly return over the period for each stock using the “shift trick” on the lecture slide titled Shifting (Note: you should end up with a time series 59 months long)

# %%
# use shift trick to calculate return
# instead of calculate each stock as Time Serie, use the data frame to do in one shock.

mreturn=df / df.shift(1) -1
mreturn.head()
# Out:
#                 aapl      msft       ibm      amzn      ebay
# Date
# 2012-07-31       NaN       NaN       NaN       NaN       NaN
# 2012-08-31  0.055659  0.034296  0.011697  0.024406  0.033119
# 2012-09-30  0.061612  0.016552  0.031623  0.070073  0.068469
# 2012-10-31 -0.068745 -0.055716 -0.005491 -0.044756 -0.007894
# 2012-11-30 -0.107478 -0.038293 -0.054473 -0.040412  0.010070

# %%
mreturn = mreturn.dropna()
mreturn
# Out:
#                 aapl      msft       ibm      amzn      ebay
# Date
# 2012-08-31  0.055659  0.034296  0.011697  0.024406  0.033119
# 2012-09-30  0.061612  0.016552  0.031623  0.070073  0.068469
# 2012-10-31 -0.068745 -0.055716 -0.005491 -0.044756 -0.007894
# ...              ...       ...       ...       ...       ...
# 2017-04-30  0.016129  0.020516 -0.053564  0.057555  0.003517
# 2017-05-31  0.068143  0.044426 -0.075523  0.064535  0.013652
# 2017-06-30 -0.027435  0.026086  0.005452  0.029860  0.027800
#
# [59 rows x 5 columns]

# %% [markdown]
# #### 6) Use pandas autocorrelation_plot to plot the autocorrelation of the monthly returns. Are they autocorrelated? Why or why not?

# %%
plt.figure(figsize=(15,5))
for s in mreturn.columns:
    pd.plotting.autocorrelation_plot(mreturn[s],label=s)
    
# by looking at the plot below, the auto-correlation for each stock is very weak, as they all lower than %25 threshold.
# the rationale could be because stock return is cyclic, but not seasonal.

# %% [markdown]
# #### 7) OPTIONAL: Visualize the correlation between the returns of all pairs of stocks using a scatterplot matrix (1 bonus mark)

# %%
pd.plotting.scatter_matrix(mreturn, diagonal='kde', figsize=(10, 10));

# %% [markdown]
# #### 8) OPTIONAL: Following the instructions in https://glowingpython.blogspot.ca/2012/10/visualizing-correlation-matrices.html visualize the correlation of the returns of all pairs of stocks (2 bonus marks)

# %%
# Using pylab to plot the return correlation between every two stocks.
# As the axis tick is available in numeric, not easy to read..

from numpy import corrcoef, arange
from pylab import pcolor, show, colorbar, xticks, yticks

# plotting the correlation matrix
R = corrcoef(mreturn.T)
pcolor(R)
colorbar()
yticks(arange(0.5,5.5),range(1,6))
xticks(arange(0.5,5.5),range(1,6))

show()

# %%
# The approach used in class demonstration is better in terms of the readability, and the result shows same pattern
# as the pylab method.

corr = mreturn.corr()[::-1]
corr
# Out:
#           aapl      msft       ibm      amzn      ebay
# ebay  0.236575  0.268987  0.174809  0.401234  1.000000
# amzn  0.263487  0.192660  0.132468  1.000000  0.401234
# ibm   0.151210  0.216203  1.000000  0.132468  0.174809
# msft  0.345257  1.000000  0.216203  0.192660  0.268987
# aapl  1.000000  0.345257  0.151210  0.263487  0.236575

# %%
plt.imshow(corr, cmap='hot', interpolation='none')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns)
plt.yticks(range(len(corr)), corr.columns[::-1]);

# %% [markdown]
# As a result, clear correlation noted between similar business, e.g., eBay and Amazon; or Apple and Microsoft.

# %% [markdown]
# # Conlusion
